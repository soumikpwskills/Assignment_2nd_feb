# %% [markdown]
# **Consider following code to answer further questions:**

# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data','Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# **Q1. Write a code to print the data present in the second row of the dataframe, df.**

# %%
# Using iloc function to display second row .
# note that index for second row is 1
print(df.iloc[1])
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# **Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?**

# %% [markdown]
# Ans :- iloc and loc are both methods used to select data from a pandas dataframe, but they use different indexing methods.
# 1. iloc is an integer-based indexing method that is used to access rows and columns by integer position. The syntax of the iloc method is df.iloc[row_positions, column_positions]. Here, row_positions and column_positions refer to the integer positions of the rows and columns, respectively. iloc returns a DataFrame that matches the specified integer positions.

# %%
df.iloc[0:2,0]
# Out:
# 0        Data Science
# 1    Machine Learning
# Name: course_name, dtype: object

# %% [markdown]
# 2. loc is a label-based indexing method that is used to access rows and columns by labels or boolean arrays. The syntax of the loc method is df.loc[row_labels, column_labels]. Here, row_labels and column_labels refer to the row and column labels, respectively. loc returns a DataFrame that matches the specified labels.

# %%
df.loc[0:1,'course_name']
# Out:
# 0        Data Science
# 1    Machine Learning
# Name: course_name, dtype: object

# %% [markdown]
# **Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].**
#
# **Did you observe any difference in both the outputs? If so then explain it.**

# %%
# Creating reindex variable
reindex = [3,0,1,2]

# Reindexing the dateframe using
new_df = df.reindex(reindex)

# Showing new_df
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
new_df.loc[2]
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# Yes, there is a difference in the outputs of new_df.loc[2] and new_df.iloc[2].
#
# new_df.loc:- Since the index of new_df is now [3, 0, 1, 2], new_df.loc[] will print the row at the label 2 in the index.
#
# new_df.iloc:- new_df.iloc[2] returns the row that has the integer position 2 in the index.

# %% [markdown]
# **Consider the below code to answer further questions:**

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.239585  0.022411  0.836311  0.819295  0.099735  0.647028
# 2  0.875545  0.713784  0.382930  0.623441  0.327984  0.495357
# 3  0.064769  0.894485  0.840023  0.055308  0.473832  0.540616
# 4  0.461907  0.720672  0.118619  0.156913  0.540502  0.408912
# 5  0.755285  0.405754  0.964473  0.218588  0.895574  0.746755
# 6  0.869683  0.990004  0.307312  0.297334  0.608982  0.215866

# %% [markdown]
# **Q4. Write a code to find the following statistical measurements for the above dataframe df1:**
#
# **(i) mean of each and every column present in the dataframe.**
#
# **(ii) standard deviation of column, ‘column_2’**

# %%
# using mean() function of pandas
df1.mean()
# Out:
# column_1    0.544462
# column_2    0.624518
# column_3    0.574945
# column_4    0.361813
# column_5    0.491102
# column_6    0.509089
# dtype: float64

# %%
# using std() function then seleting column2
df1.std()['column_2']
# Out:
# 0.3561085698457512

# %% [markdown]
# **Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.**
#
# If you are getting errors in executing it then explain why.
#
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
# Replacing column_2 with string data
df1['column_2'] = ['a','b','c','d','e','f']
df1
# Out:
#    column_1 column_2  column_3  column_4  column_5  column_6
# 1  0.239585        a  0.836311  0.819295  0.099735  0.647028
# 2  0.875545        b  0.382930  0.623441  0.327984  0.495357
# 3  0.064769        c  0.840023  0.055308  0.473832  0.540616
# 4  0.461907        d  0.118619  0.156913  0.540502  0.408912
# 5  0.755285        e  0.964473  0.218588  0.895574  0.746755
# 6  0.869683        f  0.307312  0.297334  0.608982  0.215866

# %%
df1.dtypes
# Out:
# column_1    float64
# column_2     object
# column_3    float64
# column_4    float64
# column_5    float64
# column_6    float64
# dtype: object

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: 'abcdef'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %% [markdown]
# Error is because of the string datatype used here
#
# Firstly mean = sum / number of objects.Here we will be able to get sum as abcdef in pandas, now problem will occur when dividing by number. It is not possible to divide string by a number it will give TypeError. Note that mean functionality will work only for integer and float datatypes
#
# In case if data is provided for number in strings typecast it into int or float using .astype(float) function

# %% [markdown]
# Consider below example where i have considered numbers as string in below case

# %%
df1['column_2']=['1','2','3','4','5','6']
df1
# Out:
#    column_1 column_2  column_3  column_4  column_5  column_6
# 1  0.239585        1  0.836311  0.819295  0.099735  0.647028
# 2  0.875545        2  0.382930  0.623441  0.327984  0.495357
# 3  0.064769        3  0.840023  0.055308  0.473832  0.540616
# 4  0.461907        4  0.118619  0.156913  0.540502  0.408912
# 5  0.755285        5  0.964473  0.218588  0.895574  0.746755
# 6  0.869683        6  0.307312  0.297334  0.608982  0.215866

# %%
df1.dtypes
# Out:
# column_1    float64
# column_2     object
# column_3    float64
# column_4    float64
# column_5    float64
# column_6    float64
# dtype: object

# %%
df1['column_2'].mean()
# Out:
# 20576.0

# %% [markdown]
# Why I'm getting 20576.0 for above case?
# 1. Function will do sum operation for strings i.e. sum = '123456' in this case for column 2
# 2. Function will convert string object to float now sum = 123456.0 in float
# 3. mean = sum / number of records , in this case mean = 123456/6 = 20576.0
# 4. This result is misleading and this is why we need to check datatypes and convert them using astypes function
#
# Below is correct code to calculate accurate mean for column_2 data for this example

# %%
# converting column_2 datatype to integer
df1['column_2'] = df1['column_2'].astype(int)

# %%
df1.dtypes
# Out:
# column_1    float64
# column_2      int64
# column_3    float64
# column_4    float64
# column_5    float64
# column_6    float64
# dtype: object

# %%
df1['column_2'].mean()
# Out:
# 3.5

# %% [markdown]
# **Q6. What do you understand about the windows function in pandas and list the types of windows functions?**

# %% [markdown]
# Ans :- The window functions in Pandas are used to perform some sort of calculations across a set of rows that are interrelated with the current row. The windows functions help us to perform the aggregated calculations across various partitions or cross-sections of the data.
#
# A question that comes to our mind after reading the windows function is what exactly is a window? Well, a window is a value (in terms of rows) that tells us the distance between our current row and the row which is to be used for calculations.

# %% [markdown]
# The types of window functions available in pandas can be broadly classified into the following categories:
#
# 1. Rolling functions: These functions compute a rolling statistic over a defined window size. Examples include rolling mean, rolling sum, rolling standard deviation, etc.
#
# 2. Expanding functions: These functions compute a cumulative statistic over the entire dataset up to the current point. Examples include expanding sum, expanding mean, etc.
#
# 3. Exponentially weighted functions: These functions compute a rolling statistic with weights that decay exponentially as the distance from the current point increases. Examples include exponentially weighted mean, exponentially weighted standard deviation, etc.
#
# 4. Cumulative functions: These functions compute a cumulative statistic over the entire dataset up to the current point. Examples include cumsum, cummax, cummin, etc.
#
# 5. Aggregating functions: These functions perform a groupby-style operation on a rolling or expanding window. Examples include groupby.mean(), groupby.sum(), etc.

# %% [markdown]
# **Q7. Write a code to print only the current month and year at the time of answering this question.**
# [Hint: Use pandas.datetime function]

# %%
# Getting current timestamp
timestamp_now = pd.Timestamp.now()
timestamp_now
# Out:
# Timestamp('2023-09-19 10:50:34.571545')

# %%
# Getting current month and year
month = timestamp_now.month_name()
year = timestamp_now.year

# %%
# Displaying current Month and Year
print(f'Month while writing this code is : {month}')
print(f'Year while writing this code is  : {year}')
# Out:
# Month while writing this code is : September
# Year while writing this code is  : 2023

# %% [markdown]
# **Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.**

# %%
import pandas as pd

try:
    # Prompt the user to enter the first date
    date1 = input("Enter the first date (YYYY-MM-DD): ")

    # Prompt the user to enter the second date
    date2 = input("Enter the second date (YYYY-MM-DD): ")

    # Convert the dates to datetime objects
    date1 = pd.to_datetime(date1)
    date2 = pd.to_datetime(date2)

    # Calculate the time difference between the dates
    time_diff = date2 - date1
    days =time_diff.days

    # Display the result
    print(f"The difference between {date1.date()} and {date2.date()} is {days} days")

except Exception as e:
    print('Input provided for date1 :',date1)
    print('Input provided for date2 :',date2)
    print('Exception Occured and Handled :',e)
# Out:
# Enter the first date (YYYY-MM-DD): 2022-06-25
# Enter the second date (YYYY-MM-DD): 2023-09-19
# The difference between 2022-06-25 and 2023-09-19 is 451 days

# %% [markdown]
# **Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.**

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
filepath = input('Enter the filepath: ')
column = input('Enter the column name: ')
order = input('Enter category order: ')

df = pd.read_csv(filepath)

df[column].astype('category')

if order=='ascending':
    df=df.sort_values(by = column, ascending= True)
elif order=='descending':
    df=df.sort_values(by = column, ascending= False)

df

# file path =' https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
# column = Pclass
# order = ascening
# Out:
# Enter the filepath: https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Enter the column name: Pclass
# Enter category order: ascending
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 379          380         0       3
# 381          382         1       3
# 382          383         0       3
# 371          372         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# ...

# %% [markdown]
# **Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.**

# %%
import csv

columns = ['Date', 'Product', 'Sales']

rows = [ ['2022-01-01', 'iphone', '100'],
         ['2022-01-01', 'Xiaomi', '150'],
         ['2022-01-02', 'Samsung', '120'],
         ['2022-01-02', 'iphone', '130'],
         ['2022-01-03', 'Xiaomi', '80'],
         ['2022-01-03', 'Samsung', '180'],
         ['2022-01-04', 'iphone', '90'],
         ['2022-01-04', 'Samsung', '200'],
         ['2022-01-05', 'Xiaomi', '110'],
         ['2022-01-05', 'iphone', '170']]

# name of csv file
filename = "sales.csv"

with open(filename, 'w') as csvfile:
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)

    # writing the fields
    csvwriter.writerow(columns)

    # writing the data rows
    csvwriter.writerows(rows)

# file path : sales.csv

# %%
filepath = input('Enter filepath: ')

df = pd.read_csv(filepath)
df['Date'] = pd.to_datetime(df['Date'])
grouped = df.groupby(['Product', 'Date']).sum()
pivot = grouped.unstack(level=0)
pivot.plot(kind='bar', stacked=True)
# Out:
# Enter filepath: sales.csv
# <Axes: xlabel='Date'>

# %% [markdown]
# **Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.**
#
# The program should do the following:
#
# 1. Prompt the user to enter the file path of the CSV file containing the student dataR
# 2. Read the CSV file into a Pandas DataFrameR
# 3. Calculate the mean, median, and mode of the test scores using Pandas toolsR
# 4. Display the mean, median, and mode in a table.

# %%
import csv

columns = ['Student ID', 'Test_Score']

rows = [ ['1','85'],
         ['2','90'],
         ['3','80'],
         ['4','75'],
         ['5','85'],
         ['6','82'],
         ['7','78'],
         ['8','85'],
         ['9','90'],
         ['10','85']]

# name of csv file
filename = "student_data.csv"

with open(filename, 'w') as csvfile:
    # creating a csv writer object
    csvwriter = csv.writer(csvfile)

    # writing the fields
    csvwriter.writerow(columns)

    # writing the data rows
    csvwriter.writerows(rows)

#file path = student_data.csv

# %%
filepath = input('Enter Filepath: ')

df = pd.read_csv(filepath)

mean = df['Test_Score'].mean()
median = df['Test_Score'].median()
mode = df['Test_Score'].mode()

print("+----------+----------+")
print("Statistic | Value")
print(f"Mean:    {mean}")
print(f"Median:    {median}")
print(f"Mode:    {mode}")
print("+----------+----------+")
# Out:
# Enter Filepath: student_data.csv
# +----------+----------+
# Statistic | Value
# Mean:    83.5
# Median:    85.0
# Mode:    0    85
# Name: Test_Score, dtype: int64
# +----------+----------+
